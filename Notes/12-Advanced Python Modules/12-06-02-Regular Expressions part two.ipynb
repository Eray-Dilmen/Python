# %% [markdown]
# ## Identifiers for Characters in Patterns
#
# Characters such as a digit or a single string have different codes that represent them. You can use these to build up a pattern string. Notice how these make heavy use of the backwards slash \ . Because of this when defining a pattern string for regular expression we use the format:
#
#     r'mypattern'
#
# placing the r in front of the string allows python to understand that the \ in the pattern string are not meant to be escape slashes.
#
# Below you can find a table of all the possible identifiers:

# %% [markdown]
# <table ><tr><th>Character</th><th>Description</th><th>Example Pattern Code</th><th >Exammple Match</th></tr>
#
# <tr ><td><span >\d</span></td><td>A digit</td><td>file_\d\d</td><td>file_25</td></tr>
#
# <tr ><td><span >\w</span></td><td>Alphanumeric</td><td>\w-\w\w\w</td><td>A-b_1</td></tr>
#
#
#
# <tr ><td><span >\s</span></td><td>White space</td><td>a\sb\sc</td><td>a b c</td></tr>
#
#
#
# <tr ><td><span >\D</span></td><td>A non digit</td><td>\D\D\D</td><td>ABC</td></tr>
#
# <tr ><td><span >\W</span></td><td>Non-alphanumeric</td><td>\W\W\W\W\W</td><td>*-+=)</td></tr>
#
# <tr ><td><span >\S</span></td><td>Non-whitespace</td><td>\S\S\S\S</td><td>Yoyo</td></tr></table>

# %%
import re

# %%
text = "my number is: 444-555-6666 other is: 777-888-9999"

# %%
re.search('444-555-6666',text)
# Out:
# <re.Match object; span=(14, 26), match='444-555-6666'>

# %%
# ya aradığımız numarayı bilmiyorsak ? veya milyonlaca numaraya bakmak istiyorsak ? 
# tip araması yaparak tüm numaraları bulabiliriz

# %%
re.search(r'\d\d\d-\d\d\d-\d\d\d\d',text)
# Out:
# <re.Match object; span=(14, 26), match='444-555-6666'>

# %%
# yukardaki teknik ile yalnızca ilkini basıyor, for loop ile bakalım (finditer kullanmak gerekiyor loop için)

# %%
for match in re.finditer(r'\d\d\d-\d\d\d-\d\d\d\d', text):
    print(match.group()) # group ile sadece numaraları (value'ları) çekiyoruz index numarası önemsiz
# Out:
# 444-555-6666
# 777-888-9999

# %% [markdown]
# ---
#
# Notice the repetition of \d. That is a bit of an annoyance, especially if we are looking for very long strings of numbers. Let's explore the possible quantifiers.
#
# ## Quantifiers
#
# Now that we know the special character designations, we can use them along with quantifiers to define how many we expect.

# %% [markdown]
# <table ><tr><th>Character</th><th>Description</th><th>Example Pattern Code</th><th >Exammple Match</th></tr>
#
# <tr ><td><span >+</span></td><td>Occurs one or more times</td><td>	Version \w-\w+</td><td>Version A-b1_1</td></tr>
#
# <tr ><td><span >{3}</span></td><td>Occurs exactly 3 times</td><td>\D{3}</td><td>abc</td></tr>
#
#
#
# <tr ><td><span >{2,4}</span></td><td>Occurs 2 to 4 times</td><td>\d{2,4}</td><td>123</td></tr>
#
#
#
# <tr ><td><span >{3,}</span></td><td>Occurs 3 or more</td><td>\w{3,}</td><td>anycharacters</td></tr>
#
# <tr ><td><span >\*</span></td><td>Occurs zero or more times</td><td>A\*B\*C*</td><td>AAACC</td></tr>
#
# <tr ><td><span >?</span></td><td>Once or none</td><td>plurals?</td><td>plural</td></tr></table>

# %%
#Aynı kodu tekrar buraya yazıyorum
re.search(r'\d\d\d-\d\d\d-\d\d\d\d',text)
# Out:
# <re.Match object; span=(14, 26), match='444-555-6666'>

# %%
# şimdi de kısaltılmış hali
re.search(r'\d{3}-\d{3}-\d{4}',text)
# Out:
# <re.Match object; span=(14, 26), match='444-555-6666'>

# %%
# aynı sonucu verdi

# %% [markdown]
# ---
# #### Gruplama ile mesela ilk 3 haneyi alma (ülke kodu istendiğinde vs içinden belli bir kısmı alabilmek için)

# %%
# () içine alınan her parça ayrı bir grup olur
# {3} ve {4} ifadeleri "bu karakterden belirtilen adet kadar tekrar et" anlamına gelir (\d\d\d yerine \d{3})
phone_pattern = re.compile(r'(\d{3})-(\d{3})-(\d{4})')

# %%
# Metin içinde deseni arar ve ilk eşleşmeyi Match nesnesi olarak döner
results = re.search(phone_pattern, text)

# %%
# Parametresiz veya group(0) tüm eşleşen deseni döner: '408-555-7777'
results.group()
# Out:
# '444-555-6666'

# %%
# group(1) -> '444' (1. parantez)
# group(2) -> '555' (2. parantez)
# group(3) -> '666' (3. parantez)
results.group(3)                      # bu arada kodlama index mantığının aksine 0 değil 1 den başlıyor
# Out:
# '6666'
