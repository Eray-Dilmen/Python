# %% [markdown]
# # Advanced Strings

# %%
s = 'hello world'

# %%
s.capitalize() #ilk harfi büyütüyor
# Out:
# 'Hello world'

# %%
s.upper() # tamamını büyük yapıyor
# Out:
# 'HELLO WORLD'

# %%
s.find('o') # içerisindeki ilk o'nun index sayısını veriyor
# Out:
# 4

# %%
s.count('o') # içerisindeki o sayısını veriyor
# Out:
# 2

# %%
s
# Out:
# 'hello world'

# %%
s.center(20,'z') # center your word between 20 z  # total length is 20
# Out:
# 'zzzzhello worldzzzzz'

# %%
len(s.center(20,'z'))
# Out:
# 20

# %%
print('hello\thi')
# Out:
# hello	hi

# %%
'hello\thi'.expandtabs() # not use often
# Out:
# 'hello   hi'

# %%
s = 'hello'

# %%
s.isalnum() # all characters in s is alphanumeric # true dönüyor
# Out:
# True

# %%
s.isalpha() # if they all are alphabethic
# Out:
# True

# %%
s.islower() # if all case lower
# Out:
# True

# %%
s.isspace() # arasında white space varsa true dönüyor
# Out:
# False

# %%
s.istitle() # if title case string
# Out:
# False

# %%
s.isupper() # if all is uppercase
# Out:
# False

# %%
'HELLO'.isupper()
# Out:
# True

# %%
s
# Out:
# 'hello'

# %%
s.endswith('o') # bittiği harf 'o' ise
# Out:
# True

# %%
s[-1] == 'o' # aynı şeyin farklı şekilde kontrolü
# Out:
# True

# %%
s = 'hello there!'

# %%
s.split('e') # split at 'e'
# Out:
# ['h', 'llo th', 'r', '!']

# %%
s.partition('e') # give first part before partition, give partition, give after partition
# Out:
# ('h', 'e', 'llo there!')
