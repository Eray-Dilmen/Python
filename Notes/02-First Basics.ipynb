# %%
1+3 # not almak için başına "#" koyuyoruz.
# Out:
# 4

# %%
print("hello")
print("deneme") # aynı hücrede birden fazla satır da açabiliyoruz ve çıktıları burda teker teker test edebiliyoruz
# Out:
# hello
# deneme

# %% [markdown]
# Bu şekilde sadece not almak için de satır create edebiliyoruz üst tarafta "code" olan kısmı Markdown olarak çevirmemiz yeterli oluyor. Sonrada Shift + enter yaparak bitiriyorsun

# %%
2**5 # iki asteriks koymak üssü yapıyor.
# Out:
# 32

# %%
a=5

# %%
a
# Out:
# 12

# %% [markdown]
# gördüğün üzere önceki a çıktısını tekrar çalıştırdığında a artık 12 olacaktır çünkü en son atanan değer 12 dir.
# bu yüzden örnekleri farklı farklı sayfalarda yapmak daha iyi olacaktır.

# %%
a=12

# %% [markdown]
# type fonksiyonu hangi veri tipinde olup olmadığını kontrol etmek için vardır, çünkü pythonda veri tipi declare etmiyoruz
#
# o yüzden kullanıcı veri tipi girerken sıkıntı yaşamamak için type ile girilen değerin tipini kontrol edebiliriz.
#
# .
#
#
# bu arada şöyle bir şey de gördüm bu notebooka tekrar gir çık yaptığımda hücrelerin çalışma sırası da 1 den başladı. bu sırada a yı önceden 12 olarak tanımlamama rağmen altta yazdığım type(a) ifadesi çalışmadı çünkü tanımlanmadığını idda etti ve ben de üstteki a=12 ifadesini tekrar çalıştırdıktan sonra type(a) int olarak çalıştı. ilginç bir detay satır satır işlemediğini unutmuşum :D

# %%
type(a)
# Out:
# int

# %%
my_income = 600
taxes = 0.1

tax_based_on_income = my_income * taxes

# %%
tax_based_on_income
# Out:
# 60.0
