# %% [markdown]
# ### Comparison Operators

# %%
1 == 2
# Out:
# False

# %%
print("Bye" == "bye")
print("bye" == "bye")
# Out:
# False
# True

# %%
print(2.0 == 2)
print("2" == 2)
# Out:
# True
# False

# %%
print(3!=3)
print(4!=5)
# Out:
# False
# True

# %%
print(1<2)
print(2>=5)
# Out:
# True
# False

# %% [markdown]
# ### Logical Operators to combine comparisons

# %%
2 < 3 > 10
# Out:
# False

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
1 == 1 or 2 == 3
# Out:
# True

# %%
print(not(1 == 1)) #parantezsiz de olur
print(1 != 1)
# Out:
# False
# False

# %%
# Out:
#   Cell In[23], line 1
#     gcc -Wall "compile-deez-nuts.c" compşle-deez-nuts
#               ^
# SyntaxError: invalid syntax
